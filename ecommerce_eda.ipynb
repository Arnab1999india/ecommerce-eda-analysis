# %% [markdown]
# <a href="https://colab.research.google.com/github/Arnab1999india/ecommerce-eda-analysis/blob/main/ecommerce_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Pandas version:", pd.__version__)
print("Environment setup complete!")
# Out:
# Pandas version: 2.2.2
# Environment setup complete!
